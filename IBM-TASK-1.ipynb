# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ahmet Sina Soygan**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I've been learning artificial intelligence and deep learning but something was missing. I didn't know the machine learning models and behind the stastic. So I decided to improve my machine learning side and data science is the best option to learn this area.*

# %% [markdown]
# ### This code is about functions in python. We are defining a function below this comment line.

# %%
def sum(x1,x2):
  return(x1*x2)

sum(2,3)
# Out:
# 6

# %% [markdown]
# <hr>This is horizontal rule<hr>
#
# *   Liste 1
# *   Liste 2
#
#
# 1.   Liste 3
# 2.   Liste 4
#
# <table>
#   <tr>
#     <th>Month</th>
#     <th>Savings</th>
#   </tr>
#   <tr>
#     <td>January</td>
#     <td>$100</td>
#   </tr>
# </table>
# <a href="www.facebook.com">facebook</a>
#
# ![20180725_160428.png](data:image/png;base64,...)
